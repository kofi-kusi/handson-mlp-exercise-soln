# %% [markdown]
# <a href="https://colab.research.google.com/github/kofi-kusi/handson-mlp-exercise-soln/blob/main/03_exe_soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Kusi")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
